# %%
ismi = "Asilbek"
yoshi = 18
yangimi = True

# %%
ismi = input("Ismingizni kiriting: ")
yoqtirgan_rangi = input("Yoqtirgan rangingizni kiriting: ")
print("Foydalanuvchining ismi", ismi + ", yoqtirgan rangi", yoqtirgan_rangi +".")
# Out:
# Ismingizni kiriting: Mirjalol
# Yoqtirgan rangingizni kiriting: qora
# Foydalanuvchining ismi Mirjalol, yoqtirgan rangi qora.

# %%
x = 1.6667
print(round(x))
# Out:
# 2

# %%
x = 25 + 16 * 2**2
print(x)
# Out:
# 89

# %%
x = -16
print(abs(x))
# Out:
# 16

# %%
x = [1, 3, 6]
sum(x)
# Out:
# 10

# %%
import math

x = 5.3645
print(math.pow(x, 2))
print(math.exp(x))
print(math.ceil(x))
print(math.floor(x))
# Out:
# 28.777860249999996
# 213.68436578305042
# 6
# 5

# %%
name = 'Mirjalol'
name.lower()
# Out:
# 'mirjalol'

# %%
weither = ' '
if weither == 'issiq':
  print('Bugun havo issiq')
  print('Yetarlicha suv iching')
elif weither == 'sovuq':
  print('Bugun havo sovuq. Issiqroq kiyining!')
else:
  print('Bugun havo yaxshi.')
# Out:
# Bugun havo yaxshi.

# %%
narx = 500000
soni = 60
if soni >100:
  narx = narx - narx * 0.2
elif 50 < soni > 100:
  narx = narx - narx * 0.1
else:
  narx = narx
print(f'Narxi: {narx} som.')
# Out:
# Narxi: 500000 som.

# %%
high_income = True
good_score = False

if high_income or good_score:
  print('Kredit olishga layoqatli.')
else:
  print('Kredit olishga layoqatsiz.')
# Out:
# Kredit olishga layoqatli.

# %%
name ='oybek'
if name != 'Oybek':
  print("Qanoatlantirildi.")
else:
  print('Qanoatlantirilmadi.')
# Out:
# Qanoatlantirildi.

# %%
def hello():
  print("Hello world")

# %%
hello()
# Out:
# Hello world

# %%
def greating(name):
  print(f"Salom {name}")

# %%
greating(name = "Mirjalol")
greating("Mirjalol")
# Out:
# Salom Mirjalol
# Salom Mirjalol

# %%
def full_name(last_name, first_name):
  print(f"Salom {last_name} {first_name}")

# %%
full_name('Umurzokov', 'Mirjalol') # Positional argument
full_name(last_name = "Umurzokov", first_name = "Mirjalol") # Keyword argument
# Out:
# Salom Umurzokov Mirjalol
# Salom Umurzokov Mirjalol

# %%
try:
  age = int(input("Iltimos yoshingizni kriting: "))
  print(age)
except ValueError:
  print("Yoshingizni faqat sonlarda kiriting!")
# Out:
# Iltimos yoshingizni kriting: kk
# Yoshingizni faqat sonlarda kiriting!
